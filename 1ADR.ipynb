# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/iADR')
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pandas as pd
import time
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from keras import regularizers
from sklearn import preprocessing
# Out:
# Mounted at /content/drive

# %%
data1 = np.load('./data/drugs_structure_attentivefp_ToxCast.npy')

# %%
y = pd.read_csv('./data/labels(2248).csv')

# %%
k_X_train,k_x_test,k_Y_train,k_y_test= train_test_split(data1,y,test_size=0.1,random_state=2021)

# %% [markdown]
# # models

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.multiclass import OneVsRestClassifier
import joblib

# %%
from sklearn.svm import SVC

# %%
import joblib

# %%
m1 = keras.metrics.BinaryAccuracy(name='accuracy',threshold=0.5)
m2 = keras.metrics.Precision(name='precision')
m3 = keras.metrics.Recall(name='recall')
m4 = keras.metrics.AUC(name='AUC',multi_label=True,num_labels=27,num_thresholds=498)
m5 = keras.metrics.AUC(name='AUPR',curve='PR',multi_label=True,num_labels=27,num_thresholds=498)

# %%
#SVM
results1=[]
results2=[]
results3=[]
results4=[]
results5=[]
# 运行计时部分
time_start = time.time()
print(data1.shape)

kfolder = KFold(n_splits=10,shuffle=True,random_state=2021)
for i, (tra_id,val_id) in enumerate(kfolder.split(k_X_train,k_Y_train)):
  print(f"***********fold-{i+1}***********")

  c_x_train = k_X_train[tra_id]
  c_y_train = k_Y_train.iloc[tra_id]

  c_x_valid = k_X_train[val_id]
  c_y_valid = k_Y_train.iloc[val_id]



  # scaler = preprocessing.StandardScaler().fit(c_x_train)
  # c_x_train = scaler.transform(c_x_train)

  
  # scaler = preprocessing.StandardScaler().fit(c_x_valid)
  # c_x_valid = scaler.transform(c_x_valid)



  svc = SVC(probability=True)
  model = OneVsRestClassifier(svc, n_jobs=1)
  model.fit(c_x_train, c_y_train)



  y_pre = model.predict_proba(c_x_valid)
  # nlabel = np.array(c_y_valid)
  # plabel = np.where(c_pre_valid >= 0.5,1,0)    
  # print(nlabel,nlabel.shape)
  # print(y_pre_valid)
  # print(plabel)

  # y_pre = model.predict(c_x_valid)
  # np.save('./data/masking_RF_pre'+str(i+1)+'.npy',y_pre)



  m1.update_state(c_y_valid,y_pre)
  m2.update_state(c_y_valid,y_pre)
  m3.update_state(c_y_valid,y_pre)
  m4.update_state(c_y_valid,y_pre)
  m5.update_state(c_y_valid,y_pre)



  


  # model.save('./model/model_masking_5fold'+str(i+1)+'.h5')
  # model.save('./model/attfp/RF_attfp_10fold'+str(i+1)+'.h5')

  # result1 = np.array(n1)
  results1.append(m1.result().numpy())
  results2.append(m2.result().numpy())
  results3.append(m3.result().numpy())
  results4.append(m4.result().numpy())
  results5.append(m5.result().numpy())


  print(f"{i+1}-fold cv val Accuracy score: {m1.result().numpy()}")
  print(f"{i+1}-fold cv val Precision score: {m2.result().numpy()}")
  print(f"{i+1}-fold cv val Recall score: {m3.result().numpy()}")
  print(f"{i+1}-fold cv val AUC score: {m4.result().numpy()}")
  print(f"{i+1}-fold cv val AUPR score: {m5.result().numpy()}")
  print("\n")
  # model.save_weights('./model/attfp/RF_attfp_10fold'+str(i+1)+'.h5')
  # 6、保存模型
  joblib.dump(model,'./model/attfp/SVM_attfp_10fold'+str(i+1)+'.pkl')





print("******************************************************************")
# print(np.array(results))

print(f"-Accuracy score_mean:{np.mean(results1)}")
print(f"-Accuracy score_std:{np.std(results1)}")

print(f"-Precision score_mean:{np.mean(results2)}")
print(f"-Precision score_std:{np.std(results2)}")

print(f"-Recall score_mean:{np.mean(results3)}")
print(f"-Recall score_std:{np.std(results3)}")

print(f"-AUC score_mean:{np.mean(results4)}")
print(f"-AUC score_std:{np.std(results4)}")

print(f"-AUPR score_mean:{np.mean(results5)}")
print(f"-AUPR score_std:{np.std(results5)}")






    
# 运行计时部分
time_end = time.time()
print(f"total running time: {(time_end - time_start)/60} minites")
# Out:
# (2248, 617)
# ***********fold-1***********
# 1-fold cv val Accuracy score: 0.766465961933136
# 1-fold cv val Precision score: 0.7629321813583374
# 1-fold cv val Recall score: 0.888586163520813
# 1-fold cv val AUC score: 0.5266321301460266
# 1-fold cv val AUPR score: 0.6196610927581787
#
#
# ***********fold-2***********
# WARNING:tensorflow:5 out of the last 5 calls to <function pfor.<locals>.f at 0x7fd8268860e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function pfor.<locals>.f at 0x7fd8268860e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2-fold cv val Accuracy score: 0.7594416737556458
# 2-fold cv val Precision score: 0.748701274394989
# 2-fold cv val Recall score: 0.8914489150047302
# 2-fold cv val AUC score: 0.5042441487312317
# 2-fold cv val AUPR score: 0.5967077612876892
#
#
# ***********fold-3***********
# 3-fold cv val Accuracy score: 0.7663443088531494
# 3-fold cv val Precision score: 0.7612819671630859
# 3-fold cv val Recall score: 0.8900253176689148
# 3-fold cv val AUC score: 0.49651628732681274
# 3-fold cv val AUPR score: 0.6007097959518433
#
#
# ***********fold-4***********
# 4-fold cv val Accuracy score: 0.7663606405258179
# 4-fold cv val Precision score: 0.7651505470275879
# 4-fold cv val Recall score: 0.8859212398529053
# 4-fold cv val AUC score: 0.49378761649131775
# 4-fold cv val AUPR score: 0.6043878197669983
#
#
# ***********fold-5***********
# 5-fold cv val Accuracy score: 0.7679060697555542
# 5-fold cv val Precision score: 0.7704892158508301
# 5-fold cv val Recall score: 0.8828003406524658
# 5-fold cv val AUC score: 0.4929184019565582
# 5-fold cv val AUPR score: 0.6083428859710693
#
#
# ***********fold-6***********
# 6-fold cv val Accuracy score: 0.7661636471748352
# 6-fold cv val Precision score: 0.7662721872329712
# 6-fold cv val Recall score: 0.8845362067222595
# 6-fold cv val AUC score: 0.49356162548065186
# 6-fold cv val AUPR score: 0.6053501963615417
#
#
# ***********fold-7***********
# 7-fold cv val Accuracy score: 0.7637157440185547
# 7-fold cv val Precision score: 0.7646334767341614
# 7-fold cv val Recall score: 0.8824213147163391
# 7-fold cv val AUC score: 0.4958740472793579
# 7-fold cv val AUPR score: 0.6065568327903748
#
#
# ***********fold-8***********
# 8-fold cv val Accuracy score: 0.7635257244110107
# 8-fold cv val Precision score: 0.7639214992523193
# 8-fold cv val Recall score: 0.8832887411117554
# 8-fold cv val AUC score: 0.4935634136199951
# 8-fold cv val AUPR score: 0.6052044630050659
#
#
# ***********fold-9***********
# 9-fold cv val Accuracy score: 0.7631744742393494
# 9-fold cv val Precision score: 0.7631899118423462
# 9-fold cv val Recall score: 0.8837770819664001
# 9-fold cv val AUC score: 0.4948626756668091
# 9-fold cv val AUPR score: 0.6054428815841675
#
#
# ***********fold-10***********
# 10-fold cv val Accuracy score: 0.7640284895896912
# 10-fold cv val Precision score: 0.7648853063583374
# 10-fold cv val Recall score: 0.8834723234176636
# 10-fold cv val AUC score: 0.49335917830467224
# 10-fold cv val AUPR score: 0.606000542640686
#
#
# ******************************************************************
# -Accuracy score_mean:0.7647126913070679
# -Accuracy score_std:0.002318953862413764
# -Precision score_mean:0.7631457448005676
# -Precision score_std:0.005345330573618412
# -Recall score_mean:0.8856277465820312
# -Recall score_std:0.0030833689961582422
# -AUC score_mean:0.49853190779685974
# -AUC score_std:0.00988437607884407
# -AUPR score_mean:0.6058364510536194
# -AUPR score_std:0.005571836605668068
# total running time: 13.356911357243856 minites

# %%
# 7、模型的加载使用
model2 = joblib.load('./model/attfp/SVM_attfp_10fold1.pkl')
history  = model2.fit(k_X_train,k_Y_train)
y_pre = model2.predict_proba(k_x_test)
np.save('./model/attfp/attfp_svm_pre.npy',y_pre)



m1.update_state(k_y_test,y_pre)
m2.update_state(k_y_test,y_pre)
m3.update_state(k_y_test,y_pre)
m4.update_state(k_y_test,y_pre)
m5.update_state(k_y_test,y_pre)



print(f"Accuracy score: {m1.result().numpy()}")
print(f"Precision score: {m2.result().numpy()}")
print(f"Recall score: {m3.result().numpy()}")
print(f"AUC score: {m4.result().numpy()}")
print(f"AUPR score: {m5.result().numpy()}")
# Out:
# Accuracy score: 0.7655858397483826
# Precision score: 0.768079936504364
# Recall score: 0.8830475807189941
# AUC score: 0.49486643075942993
# AUPR score: 0.6095637679100037

# %%
results1=[]
results2=[]
results3=[]
results4=[]
results5=[]
# 运行计时部分
time_start = time.time()
print(data1.shape)

kfolder = KFold(n_splits=10,shuffle=True,random_state=2021)
for i, (tra_id,val_id) in enumerate(kfolder.split(k_X_train,k_Y_train)):
  print(f"***********fold-{i+1}***********")

  c_x_train = k_X_train[tra_id]
  c_y_train = k_Y_train.iloc[tra_id]

  c_x_valid = k_X_train[val_id]
  c_y_valid = k_Y_train.iloc[val_id]



  # scaler = preprocessing.StandardScaler().fit(c_x_train)
  # c_x_train = scaler.transform(c_x_train)

  
  # scaler = preprocessing.StandardScaler().fit(c_x_valid)
  # c_x_valid = scaler.transform(c_x_valid)



  rf = RandomForestClassifier(n_estimators=100)
  model = OneVsRestClassifier(rf, n_jobs=-1)
  history = model.fit(c_x_train, c_y_train)



  y_pre = model.predict_proba(c_x_valid)
  # nlabel = np.array(c_y_valid)
  # plabel = np.where(c_pre_valid >= 0.5,1,0)    
  # print(nlabel,nlabel.shape)
  # print(y_pre_valid)
  # print(plabel)

  # y_pre = model.predict(c_x_valid)
  # np.save('./data/masking_RF_pre'+str(i+1)+'.npy',y_pre)



  m1.update_state(c_y_valid,y_pre)
  m2.update_state(c_y_valid,y_pre)
  m3.update_state(c_y_valid,y_pre)
  m4.update_state(c_y_valid,y_pre)
  m5.update_state(c_y_valid,y_pre)



  


  # model.save('./model/model_masking_5fold'+str(i+1)+'.h5')
  # model.save('./model/attfp/RF_attfp_10fold'+str(i+1)+'.h5')

  # result1 = np.array(n1)
  results1.append(m1.result().numpy())
  results2.append(m2.result().numpy())
  results3.append(m3.result().numpy())
  results4.append(m4.result().numpy())
  results5.append(m5.result().numpy())


  print(f"{i+1}-fold cv val Accuracy score: {m1.result().numpy()}")
  print(f"{i+1}-fold cv val Precision score: {m2.result().numpy()}")
  print(f"{i+1}-fold cv val Recall score: {m3.result().numpy()}")
  print(f"{i+1}-fold cv val AUC score: {m4.result().numpy()}")
  print(f"{i+1}-fold cv val AUPR score: {m5.result().numpy()}")
  print("\n")
  # model.save_weights('./model/attfp/RF_attfp_10fold'+str(i+1)+'.h5')
  # 6、保存模型
  joblib.dump(model,'./model/attfp/RF_attfp_10fold'+str(i+1)+'.pkl')





print("******************************************************************")
# print(np.array(results))

print(f"-Accuracy score_mean:{np.mean(results1)}")
print(f"-Accuracy score_std:{np.std(results1)}")

print(f"-Precision score_mean:{np.mean(results2)}")
print(f"-Precision score_std:{np.std(results2)}")

print(f"-Recall score_mean:{np.mean(results3)}")
print(f"-Recall score_std:{np.std(results3)}")

print(f"-AUC score_mean:{np.mean(results4)}")
print(f"-AUC score_std:{np.std(results4)}")

print(f"-AUPR score_mean:{np.mean(results5)}")
print(f"-AUPR score_std:{np.std(results5)}")






    
# 运行计时部分
time_end = time.time()
print(f"total running time: {(time_end - time_start)/60} minites")
# Out:
# (2248, 617)
# ***********fold-1***********
# 1-fold cv val Accuracy score: 0.7228607535362244
# 1-fold cv val Precision score: 0.7643746137619019
# 1-fold cv val Recall score: 0.7808053493499756
# 1-fold cv val AUC score: 0.5760380625724792
# 1-fold cv val AUPR score: 0.6487594246864319
#
#
# ***********fold-2***********
# WARNING:tensorflow:5 out of the last 5 calls to <function pfor.<locals>.f at 0x7fe11428cb00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function pfor.<locals>.f at 0x7fe114274f80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2-fold cv val Accuracy score: 0.7193942666053772
# 2-fold cv val Precision score: 0.7466899752616882
# 2-fold cv val Recall score: 0.7935673594474792
# 2-fold cv val AUC score: 0.5711253881454468
# 2-fold cv val AUPR score: 0.6351576447486877
#
#
# ***********fold-3***********
# 3-fold cv val Accuracy score: 0.7200024127960205
# 3-fold cv val Precision score: 0.7564963698387146
# 3-fold cv val Recall score: 0.7871392369270325
# 3-fold cv val AUC score: 0.564655065536499
# 3-fold cv val AUPR score: 0.6381049752235413
#
#
# ***********fold-4***********
# 4-fold cv val Accuracy score: 0.7218340635299683
# 4-fold cv val Precision score: 0.7604537606239319
# 4-fold cv val Recall score: 0.7889693379402161
# 4-fold cv val AUC score: 0.5649638772010803
# 4-fold cv val AUPR score: 0.6396005153656006
#
#
# ***********fold-5***********
# 5-fold cv val Accuracy score: 0.7228986620903015
# 5-fold cv val Precision score: 0.7638141512870789
# 5-fold cv val Recall score: 0.7905737161636353
# 5-fold cv val AUC score: 0.560632586479187
# 5-fold cv val AUPR score: 0.6414333581924438
#
#
# ***********fold-6***********
# 6-fold cv val Accuracy score: 0.7222374677658081
# 6-fold cv val Precision score: 0.7617685794830322
# 6-fold cv val Recall score: 0.789161741733551
# 6-fold cv val AUC score: 0.5643665194511414
# 6-fold cv val AUPR score: 0.6383396983146667
#
#
# ***********fold-7***********
# 7-fold cv val Accuracy score: 0.7207454442977905
# 7-fold cv val Precision score: 0.7600879073143005
# 7-fold cv val Recall score: 0.7890816926956177
# 7-fold cv val AUC score: 0.5632235407829285
# 7-fold cv val AUPR score: 0.638679027557373
#
#
# ***********fold-8***********
# 8-fold cv val Accuracy score: 0.7214101552963257
# 8-fold cv val Precision score: 0.7598985433578491
# 8-fold cv val Recall score: 0.7907792329788208
# 8-fold cv val AUC score: 0.5643180012702942
# 8-fold cv val AUPR score: 0.6390060186386108
#
#
# ***********fold-9***********
# 9-fold cv val Accuracy score: 0.7214188575744629
# 9-fold cv val Precision score: 0.7602401375770569
# 9-fold cv val Recall score: 0.7897860407829285
# 9-fold cv val AUC score: 0.5661194324493408
# 9-fold cv val AUPR score: 0.6401652693748474
#
#
# ***********fold-10***********
# 10-fold cv val Accuracy score: 0.7214441299438477
# 10-fold cv val Precision score: 0.761584997177124
# 10-fold cv val Recall score: 0.7888048887252808
# 10-fold cv val AUC score: 0.5655760765075684
# 10-fold cv val AUPR score: 0.6410625576972961
#
#
# ******************************************************************
# -Accuracy score_mean:0.7214246392250061
# -Accuracy score_std:0.0010803034529089928
# -Precision score_mean:0.759540855884552
# -Precision score_std:0.004763728938996792
# -Recall score_mean:0.7888668775558472
# -Recall score_std:0.0031245832797139883
# -AUC score_mean:0.5661017894744873
# -AUC score_std:0.0041475314646959305
# -AUPR score_mean:0.6400308609008789
# -AUPR score_std:0.0033558537252247334
# total running time: 13.442054331302643 minites

# %%
# 7、模型的加载使用
# model2 = joblib.load('./model/attfp/RF_attfp_10fold1.pkl')
# history  = model2.fit(k_X_train,k_Y_train)
# y_pre = model2.predict_proba(k_x_test)
np.save('./model/attfp/attfp_RF_pre.npy',y_pre)



m1.update_state(k_y_test,y_pre)
m2.update_state(k_y_test,y_pre)
m3.update_state(k_y_test,y_pre)
m4.update_state(k_y_test,y_pre)
m5.update_state(k_y_test,y_pre)



print(f"Accuracy score: {m1.result().numpy()}")
print(f"Precision score: {m2.result().numpy()}")
print(f"Recall score: {m3.result().numpy()}")
print(f"AUC score: {m4.result().numpy()}")
print(f"AUPR score: {m5.result().numpy()}")
# Out:
# Accuracy score: 0.7247307896614075
# Precision score: 0.7671767473220825
# Recall score: 0.7916676998138428
# AUC score: 0.5669411420822144
# AUPR score: 0.6461448073387146

# %%
m1.update_state(k_y_test,y_pre)
m2.update_state(k_y_test,y_pre)
m3.update_state(k_y_test,y_pre)
m4.update_state(k_y_test,y_pre)
m5.update_state(k_y_test,y_pre)



print(f"Accuracy score: {m1.result().numpy()}")
print(f"Precision score: {m2.result().numpy()}")
print(f"Recall score: {m3.result().numpy()}")
print(f"AUC score: {m4.result().numpy()}")
print(f"AUPR score: {m5.result().numpy()}")
# Out:
# Accuracy score: 0.7227494120597839
# Precision score: 0.7642119526863098
# Recall score: 0.79008948802948
# AUC score: 0.566394567489624
# AUPR score: 0.6436620354652405

# %% [markdown]
# # deepDDI

# %%
METRICS = [
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.AUC(name='auc',multi_label=True,num_labels=27,num_thresholds=498),
      keras.metrics.AUC(name='prc',curve='PR',multi_label=True,num_labels=27,num_thresholds=498), # precision-recall curve
]

def create_model_DDI(metrics=METRICS):
  model = Sequential([
    layers.Flatten(name="my_intermediate_layer"),
    layers.Dropout(0.5),
    layers.Dense(2048),
    layers.ReLU(),
    layers.Dropout(0.5),
    layers.Dense(2048),
    layers.ReLU(),
    layers.Dropout(0.5),
    layers.Dense(2048),
    layers.ReLU(),
    layers.Dropout(0.5),
    layers.Dense(2048),
    layers.ReLU(),
    layers.Dropout(0.5),
    layers.Dense(2048),
    layers.ReLU(),
    layers.Dropout(0.5),
    layers.Dense(2048),
    layers.ReLU(),
    layers.Dropout(0.5),
    layers.Dense(2048),
    layers.ReLU(),
    layers.Dropout(0.5),
    layers.Dense(2048),
    layers.ReLU(),
    layers.Dropout(0.5),
    layers.Dense(27, activation='sigmoid', name="my_last_layer"),
    ])
  return model

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau#回调函数
# # 定义回调函数：保存最优模型                     
checkpoint = ModelCheckpoint("./data/fp_cross-model.h5",
                             monitor="val_loss",
                             mode="min",
                             save_best_only = True,
                             save_weights_only=False,
                             verbose=1)
# 定义回调函数：提前终止训练
earlystop = EarlyStopping(monitor = 'val_loss', 
                          min_delta = 0.0001, 
                          patience = 30,
                          verbose = 3,
                          mode = 'min',
                          restore_best_weights = True)
# 定义回调函数：学习率衰减
reduce_lr = ReduceLROnPlateau(monitor = 'val_loss',
                              factor = 0.2,
                              patience = 5,
                              verbose = 1,
                              min_delta = 0.0001)

# 将回调函数组织为回调列表
callbacks = [earlystop,reduce_lr]

# %%
results=[]
# 运行计时部分
time_start = time.time()
print(data1.shape)

kfolder = KFold(n_splits=10,shuffle=True,random_state=2021)
for i, (tra_id,val_id) in enumerate(kfolder.split(k_X_train,k_Y_train)):
  print(f"***********fold-{i+1}***********")

  c_x_train = k_X_train[tra_id]
  c_y_train = k_Y_train.iloc[tra_id]

  c_x_valid = k_X_train[val_id]
  c_y_valid = k_Y_train.iloc[val_id]



  model = create_model_DDI()





  opt = Adam(learning_rate=0.001)
  model.compile(loss='binary_crossentropy', optimizer=opt, metrics=METRICS)
    
  # training
  history = model.fit(c_x_train,c_y_train,epochs=300,batch_size=128,
                      validation_data=(c_x_valid, c_y_valid.values),callbacks=callbacks,)
  


  y_pre = model.predict(c_x_valid)
  # y_pre1 = model.predict(k_x_test)
  # np.save('./data/FP_DDI__pre'+str(i+1)+'.npy',y_pre)

  baseline_results = model.evaluate(c_x_valid, c_y_valid.values, verbose=0)
  for name, value in zip(model.metrics_names, baseline_results):
    print(name, ': ', value)
  print()


  model.save_weights('./model/attfp/DDI_attfp_10fold'+str(i+1)+'.h5')

  result = np.array(baseline_results)
  results.append(result)



print("******************************************************************")
# print(np.array(results))

print(f"-Accuracy score_mean:{np.mean(np.array(results)[:,[1]])}")
# print(f"-Accuracy score_mean:{np.array(results)[:,[1]]}")
print(f"-Accuracy score_mean:{np.std(np.array(results)[:,[1]])}")

print(f"-Precision score_mean:{np.mean(np.array(results)[:,[2]])}")
print(f"-Precision score_mean:{np.std(np.array(results)[:,[2]])}")

print(f"-Recall score_mean:{np.mean(np.array(results)[:,[3]])}")
print(f"-Recall score_mean:{np.std(np.array(results)[:,[3]])}")

print(f"-AUC score_mean:{np.mean(np.array(results)[:,[4]])}")
print(f"-AUC score_mean:{np.std(np.array(results)[:,[4]])}")

print(f"-AUPR score_mean:{np.mean(np.array(results)[:,[5]])}")
print(f"-AUPR score_mean:{np.std(np.array(results)[:,[5]])}")






    
# 运行计时部分
time_end = time.time()
print(f"total running time: {(time_end - time_start)/60} minites")
# Out:
# (2248, 617)
# ***********fold-1***********
# Epoch 1/300
# 15/15 [==============================] - 16s 817ms/step - loss: 0.6304 - precision: 0.7485 - recall: 0.8227 - accuracy: 0.7239 - auc: 0.4943 - prc: 0.6027 - val_loss: 0.5679 - val_precision: 0.7565 - val_recall: 0.8834 - val_accuracy: 0.7584 - val_auc: 0.5296 - val_prc: 0.5971 - lr: 0.0010
# Epoch 2/300
# 15/15 [==============================] - 11s 747ms/step - loss: 0.5347 - precision: 0.7599 - recall: 0.8687 - accuracy: 0.7530 - auc: 0.4877 - prc: 0.5978 - val_loss: 0.5654 - val_precision: 0.7387 - val_recall: 0.9216 - val_accuracy: 0.7562 - val_auc: 0.5350 - val_prc: 0.6014 - lr: 0.0010
# Epoch 3/300
# 15/15 [==============================] - 11s 734ms/step - loss: 0.5214 - precision: 0.7581 - recall: 0.8796 - accuracy: 0.7559 - auc: 0.4962 - prc: 0.6012 - val_loss: 0.5623 - val_precision: 0.7696 - val_recall: 0.8526 - val_accuracy: 0.7573 - val_auc: 0.5529 - val_prc: 0.6187 - lr: 0.0010
# Epoch 4/300
# 15/15 [==============================] - 11s 737ms/step - loss: 0.5129 - precision: 0.7590 - recall: 0.8753 - accuracy: 0.7549 - auc: 0.5072 - prc: 0.6111 - val_loss: 0.5504 - val_precision: 0.7464 - val_recall: 0.9089 - val_accuracy: 0.7590 - val_auc: 0.5478 - val_prc: 0.6063 - lr: 0.0010
# Epoch 5/300
# 15/15 [==============================] - 11s 731ms/step - loss: 0.5088 - precision: 0.7604 - recall: 0.8769 - accuracy: 0.7569 - auc: 0.5250 - prc: 0.6205 - val_loss: 0.5725 - val_precision: 0.7636 - val_recall: 0.8625 - val_accuracy: 0.7562 - val_auc: 0.5469 - val_prc: 0.6058 - lr: 0.0010
# Epoch 6/300
# 15/15 [==============================] - 11s 743ms/step - loss: 0.5142 - precision: 0.7668 - recall: 0.8646 - accuracy: 0.7576 - auc: 0.5143 - prc: 0.6120 - val_loss: 0.5597 - val_precision: 0.7565 - val_recall: 0.8834 - val_accuracy: 0.7584 - val_auc: 0.5221 - val_prc: 0.6005 - lr: 0.0010
# 15/15 [==============================] - 12s 767ms/step - loss: 0.4991 - precision: 0.7603 - recall: 0.8839 - accuracy: 0.7606 - auc: 0.5468 - prc: 0.6261 - val_loss: 0.4878 - val_precision: 0.7756 - val_recall: 0.8926 - val_accuracy: 0.7728 - val_auc: 0.5540 - val_prc: 0.6450 - lr: 6.4000e-08
# Epoch 63/300
# 15/15 [==============================] - 12s 766ms/step - loss: 0.4994 - precision: 0.7606 - recall: 0.8852 - accuracy: 0.7614 - auc: 0.5462 - prc: 0.6241 - val_loss: 0.4878 - val_precision: 0.7756 - val_recall: 0.8926 - val_accuracy: 0.7728 - val_auc: 0.5539 - val_prc: 0.6450 - lr: 6.4000e-08
# Epoch 64/300
# 15/15 [==============================] - ETA: 0s - loss: 0.4989 - precision: 0.7600 - recall: 0.8839 - accuracy: 0.7602 - auc: 0.5538 - prc: 0.6254Restoring model weights from the end of the best epoch: 34.
#
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 1.2800001059076749e-08.
# 15/15 [==============================] - 12s 776ms/step - loss: 0.4989 - precision: 0.7600 - recall: 0.8839 - accuracy: 0.7602 - auc: 0.5538 - prc: 0.6254 - val_loss: 0.4878 - val_precision: 0.7756 - val_recall: 0.8926 - val_accuracy: 0.7728 - val_auc: 0.5538 - val_prc: 0.6449 - lr: 6.4000e-08
# Epoch 00064: early stopping
# loss :  0.487173855304718
# precision :  0.7747126221656799
# recall :  0.894954264163971
# accuracy :  0.7730107307434082
# auc :  0.548876941204071
# prc :  0.6417518854141235
#
# ******************************************************************
# -Accuracy score_mean:0.761611407995224
# -Accuracy score_mean:0.017304615629466804
# -Precision score_mean:0.8854149222373963
# -Precision score_mean:0.013772868384349173
# -Recall score_mean:0.7617402791976928
# -Recall score_mean:0.010380762335461416
# -AUC score_mean:0.553580367565155
# -AUC score_mean:0.01629700372458652
# -AUPR score_mean:0.6271515727043152
# -AUPR score_mean:0.012811358541338141
# total running time: 122.09991030693054 minites

# %%
#加载模型
from keras.models import load_model
# model.load_weights(‘model_weights.h5')
model2 = create_model_DDI()

model2.build(k_X_train.shape)#加这一步有了解决

model2.load_weights('./model/attfp/DDI_attfp_10fold10.h5')

opt = Adam(learning_rate=0.001)
model2.compile(loss='binary_crossentropy', optimizer=opt, metrics=METRICS)
model2.fit(k_X_train,k_Y_train,batch_size=128, epochs=300,validation_data=(k_x_test,k_y_test),callbacks=[earlystop])
model2.evaluate(k_x_test,k_y_test,return_dict=True)
y_pre = model2.predict(k_x_test)
np.save('./model/attfp/attfp_DDI_pre.npy',y_pre)
# Out:
# Epoch 1/300
# 16/16 [==============================] - 20s 961ms/step - loss: 0.5032 - precision: 0.7636 - recall: 0.8783 - accuracy: 0.7607 - auc: 0.5297 - prc: 0.6159 - val_loss: 0.4832 - val_precision: 0.7929 - val_recall: 0.8779 - val_accuracy: 0.7755 - val_auc: 0.5709 - val_prc: 0.6693
# Epoch 2/300
# 16/16 [==============================] - 14s 862ms/step - loss: 0.5020 - precision: 0.7630 - recall: 0.8784 - accuracy: 0.7601 - auc: 0.5354 - prc: 0.6202 - val_loss: 0.4899 - val_precision: 0.8164 - val_recall: 0.8137 - val_accuracy: 0.7641 - val_auc: 0.5631 - val_prc: 0.6613
