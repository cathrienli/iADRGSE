# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/iADR')
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pandas as pd
import time
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from keras import regularizers
from sklearn import preprocessing
# Out:
# Mounted at /content/drive

# %%
data1 = np.load('./data/gin_supervised_contextpred.npy')

y = pd.read_csv('./data/labels(2248).csv')
k_X_train,k_x_test,k_Y_train,k_y_test= train_test_split(data1,y,test_size=0.1,random_state=2021)

# %% [markdown]
# # model

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.multiclass import OneVsRestClassifier
import joblib

# %%
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
import joblib

# %%
m1 = keras.metrics.BinaryAccuracy(name='accuracy',threshold=0.5)
m2 = keras.metrics.Precision(name='precision')
m3 = keras.metrics.Recall(name='recall')
m4 = keras.metrics.AUC(name='AUC',multi_label=True,num_labels=27,num_thresholds=498)
m5 = keras.metrics.AUC(name='AUPR',curve='PR',multi_label=True,num_labels=27,num_thresholds=498)

# %%
results1=[]
results2=[]
results3=[]
results4=[]
results5=[]
# 运行计时部分
time_start = time.time()
print(data1.shape)

kfolder = KFold(n_splits=10,shuffle=True,random_state=2021)
for i, (tra_id,val_id) in enumerate(kfolder.split(k_X_train,k_Y_train)):
  print(f"***********fold-{i+1}***********")

  c_x_train = k_X_train[tra_id]
  c_y_train = k_Y_train.iloc[tra_id]

  c_x_valid = k_X_train[val_id]
  c_y_valid = k_Y_train.iloc[val_id]



  # scaler = preprocessing.StandardScaler().fit(c_x_train)
  # c_x_train = scaler.transform(c_x_train)

  
  # scaler = preprocessing.StandardScaler().fit(c_x_valid)
  # c_x_valid = scaler.transform(c_x_valid)



  svc = SVC(probability=True)
  model = OneVsRestClassifier(svc, n_jobs=1)
  model.fit(c_x_train, c_y_train)



  y_pre = model.predict_proba(c_x_valid)
  # nlabel = np.array(c_y_valid)
  # plabel = np.where(c_pre_valid >= 0.5,1,0)    
  # print(nlabel,nlabel.shape)
  # print(y_pre_valid)
  # print(plabel)

  # y_pre = model.predict(c_x_valid)
  # np.save('./data/masking_RF_pre'+str(i+1)+'.npy',y_pre)



  m1.update_state(c_y_valid,y_pre)
  m2.update_state(c_y_valid,y_pre)
  m3.update_state(c_y_valid,y_pre)
  m4.update_state(c_y_valid,y_pre)
  m5.update_state(c_y_valid,y_pre)



  


  # model.save('./model/model_masking_5fold'+str(i+1)+'.h5')
  # model.save('./model/attfp/RF_attfp_10fold'+str(i+1)+'.h5')

  # result1 = np.array(n1)
  results1.append(m1.result().numpy())
  results2.append(m2.result().numpy())
  results3.append(m3.result().numpy())
  results4.append(m4.result().numpy())
  results5.append(m5.result().numpy())


  print(f"{i+1}-fold cv val Accuracy score: {m1.result().numpy()}")
  print(f"{i+1}-fold cv val Precision score: {m2.result().numpy()}")
  print(f"{i+1}-fold cv val Recall score: {m3.result().numpy()}")
  print(f"{i+1}-fold cv val AUC score: {m4.result().numpy()}")
  print(f"{i+1}-fold cv val AUPR score: {m5.result().numpy()}")
  print("\n")
  # model.save_weights('./model/attfp/RF_attfp_10fold'+str(i+1)+'.h5')
  # 6、保存模型
  joblib.dump(model,'./model/context/SVM_context_10fold'+str(i+1)+'.pkl')





print("******************************************************************")
# print(np.array(results))

print(f"-Accuracy score_mean:{np.mean(results1)}")
print(f"-Accuracy score_std:{np.std(results1)}")

print(f"-Precision score_mean:{np.mean(results2)}")
print(f"-Precision score_std:{np.std(results2)}")

print(f"-Recall score_mean:{np.mean(results3)}")
print(f"-Recall score_std:{np.std(results3)}")

print(f"-AUC score_mean:{np.mean(results4)}")
print(f"-AUC score_std:{np.std(results4)}")

print(f"-AUPR score_mean:{np.mean(results5)}")
print(f"-AUPR score_std:{np.std(results5)}")






    
# 运行计时部分
time_end = time.time()
print(f"total running time: {(time_end - time_start)/60} minites")
# Out:
# (2248, 300)
# ***********fold-1***********
# 1-fold cv val Accuracy score: 0.7952929139137268
# 1-fold cv val Precision score: 0.7970580458641052
# 1-fold cv val Recall score: 0.885861337184906
# 1-fold cv val AUC score: 0.7055668234825134
# 1-fold cv val AUPR score: 0.7222411036491394
#
#
# ***********fold-2***********
# WARNING:tensorflow:5 out of the last 5 calls to <function pfor.<locals>.f at 0x7f896e41c680> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function pfor.<locals>.f at 0x7f896e41ce60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2-fold cv val Accuracy score: 0.7916438579559326
# 2-fold cv val Precision score: 0.7826733589172363
# 2-fold cv val Recall score: 0.8954693078994751
# 2-fold cv val AUC score: 0.7042564749717712
# 2-fold cv val AUPR score: 0.7124393582344055
#
#
# ***********fold-3***********
# 3-fold cv val Accuracy score: 0.7951104044914246
# 3-fold cv val Precision score: 0.7932744026184082
# 3-fold cv val Recall score: 0.8910380005836487
# 3-fold cv val AUC score: 0.6940634250640869
# 3-fold cv val AUPR score: 0.7142327427864075
#
#
# ***********fold-4***********
# 4-fold cv val Accuracy score: 0.7969585657119751
# 4-fold cv val Precision score: 0.7993068099021912
# 4-fold cv val Recall score: 0.8873547315597534
# 4-fold cv val AUC score: 0.6973719000816345
# 4-fold cv val AUPR score: 0.7210425734519958
#
#
# ***********fold-5***********
# 5-fold cv val Accuracy score: 0.798142671585083
# 5-fold cv val Precision score: 0.8038714528083801
# 5-fold cv val Recall score: 0.8853754997253418
# 5-fold cv val AUC score: 0.693484902381897
# 5-fold cv val AUPR score: 0.7216644883155823
#
#
# ***********fold-6***********
# 6-fold cv val Accuracy score: 0.7965859174728394
# 6-fold cv val Precision score: 0.8008089661598206
# 6-fold cv val Recall score: 0.8849881887435913
# 6-fold cv val AUC score: 0.6935549378395081
# 6-fold cv val AUPR score: 0.7205767035484314
#
#
# ***********fold-7***********
# 7-fold cv val Accuracy score: 0.79411381483078
# 7-fold cv val Precision score: 0.7995472550392151
# 7-fold cv val Recall score: 0.8819907903671265
# 7-fold cv val AUC score: 0.6929529905319214
# 7-fold cv val AUPR score: 0.722613513469696
#
#
# ***********fold-8***********
# 8-fold cv val Accuracy score: 0.7934252619743347
# 8-fold cv val Precision score: 0.7989407181739807
# 8-fold cv val Recall score: 0.8814038634300232
# 8-fold cv val AUC score: 0.6879818439483643
# 8-fold cv val AUPR score: 0.718631386756897
#
#
# ***********fold-9***********
# 9-fold cv val Accuracy score: 0.793316662311554
# 9-fold cv val Precision score: 0.7990750670433044
# 9-fold cv val Recall score: 0.8806921243667603
# 9-fold cv val AUC score: 0.6881638765335083
# 9-fold cv val AUPR score: 0.7198509573936462
#
#
# ***********fold-10***********
# 10-fold cv val Accuracy score: 0.7939803004264832
# 10-fold cv val Precision score: 0.8006956577301025
# 10-fold cv val Recall score: 0.880280613899231
# 10-fold cv val AUC score: 0.6865084171295166
# 10-fold cv val AUPR score: 0.7194920182228088
#
#
# ******************************************************************
# -Accuracy score_mean:0.7948570251464844
# -Accuracy score_std:0.0018580455798655748
# -Precision score_mean:0.7975252270698547
# -Precision score_std:0.0055825007148087025
# -Recall score_mean:0.8854454159736633
# -Recall score_std:0.004618716426193714
# -AUC score_mean:0.694390594959259
# -AUC score_std:0.0061383796855807304
# -AUPR score_mean:0.7192784547805786
# -AUPR score_std:0.00321582262404263
# total running time: 10.46724716424942 minites

# %%
results1=[]
results2=[]
results3=[]
results4=[]
results5=[]
# 运行计时部分
time_start = time.time()
print(data1.shape)

kfolder = KFold(n_splits=10,shuffle=True,random_state=2021)
for i, (tra_id,val_id) in enumerate(kfolder.split(k_X_train,k_Y_train)):
  print(f"***********fold-{i+1}***********")

  c_x_train = k_X_train[tra_id]
  c_y_train = k_Y_train.iloc[tra_id]

  c_x_valid = k_X_train[val_id]
  c_y_valid = k_Y_train.iloc[val_id]



  # scaler = preprocessing.StandardScaler().fit(c_x_train)
  # c_x_train = scaler.transform(c_x_train)

  
  # scaler = preprocessing.StandardScaler().fit(c_x_valid)
  # c_x_valid = scaler.transform(c_x_valid)



  rf = RandomForestClassifier(n_estimators=100)
  model = OneVsRestClassifier(rf, n_jobs=-1)
  history = model.fit(c_x_train, c_y_train)



  y_pre = model.predict_proba(c_x_valid)
  # nlabel = np.array(c_y_valid)
  # plabel = np.where(c_pre_valid >= 0.5,1,0)    
  # print(nlabel,nlabel.shape)
  # print(y_pre_valid)
  # print(plabel)

  # y_pre = model.predict(c_x_valid)
  # np.save('./data/masking_RF_pre'+str(i+1)+'.npy',y_pre)



  m1.update_state(c_y_valid,y_pre)
  m2.update_state(c_y_valid,y_pre)
  m3.update_state(c_y_valid,y_pre)
  m4.update_state(c_y_valid,y_pre)
  m5.update_state(c_y_valid,y_pre)



  


  # model.save('./model/model_masking_5fold'+str(i+1)+'.h5')
  # model.save('./model/attfp/RF_attfp_10fold'+str(i+1)+'.h5')

  # result1 = np.array(n1)
  results1.append(m1.result().numpy())
  results2.append(m2.result().numpy())
  results3.append(m3.result().numpy())
  results4.append(m4.result().numpy())
  results5.append(m5.result().numpy())


  print(f"{i+1}-fold cv val Accuracy score: {m1.result().numpy()}")
  print(f"{i+1}-fold cv val Precision score: {m2.result().numpy()}")
  print(f"{i+1}-fold cv val Recall score: {m3.result().numpy()}")
  print(f"{i+1}-fold cv val AUC score: {m4.result().numpy()}")
  print(f"{i+1}-fold cv val AUPR score: {m5.result().numpy()}")
  print("\n")
  # model.save_weights('./model/attfp/RF_attfp_10fold'+str(i+1)+'.h5')
  # 6、保存模型
  joblib.dump(model,'./model/context/RF_context_10fold'+str(i+1)+'.pkl')





print("******************************************************************")
# print(np.array(results))

print(f"-Accuracy score_mean:{np.mean(results1)}")
print(f"-Accuracy score_std:{np.std(results1)}")

print(f"-Precision score_mean:{np.mean(results2)}")
print(f"-Precision score_std:{np.std(results2)}")

print(f"-Recall score_mean:{np.mean(results3)}")
print(f"-Recall score_std:{np.std(results3)}")

print(f"-AUC score_mean:{np.mean(results4)}")
print(f"-AUC score_std:{np.std(results4)}")

print(f"-AUPR score_mean:{np.mean(results5)}")
print(f"-AUPR score_std:{np.std(results5)}")






    
# 运行计时部分
time_end = time.time()
print(f"total running time: {(time_end - time_start)/60} minites")
# Out:
# (2248, 300)
# ***********fold-1***********
# 1-fold cv val Accuracy score: 0.8016784191131592
# 1-fold cv val Precision score: 0.8112359642982483
# 1-fold cv val Recall score: 0.8743566274642944
# 1-fold cv val AUC score: 0.7137302756309509
# 1-fold cv val AUPR score: 0.7424851059913635
#
#
# ***********fold-2***********
# WARNING:tensorflow:5 out of the last 5 calls to <function pfor.<locals>.f at 0x7f467e48e7a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function pfor.<locals>.f at 0x7f467e48e8c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2-fold cv val Accuracy score: 0.8003101348876953
# 2-fold cv val Precision score: 0.7979938983917236
# 2-fold cv val Recall score: 0.8857275247573853
# 2-fold cv val AUC score: 0.7190737724304199
# 2-fold cv val AUPR score: 0.7302218675613403
#
#
# ***********fold-3***********
# 3-fold cv val Accuracy score: 0.7977254390716553
# 3-fold cv val Precision score: 0.8032225370407104
# 3-fold cv val Recall score: 0.878379762172699
# 3-fold cv val AUC score: 0.7083550691604614
# 3-fold cv val AUPR score: 0.727481484413147
#
#
# ***********fold-4***********
# 4-fold cv val Accuracy score: 0.7985568642616272
# 4-fold cv val Precision score: 0.810215413570404
# 4-fold cv val Recall score: 0.8712841272354126
# 4-fold cv val AUC score: 0.7056825160980225
# 4-fold cv val AUPR score: 0.7336318492889404
#
#
# ***********fold-5***********
# 5-fold cv val Accuracy score: 0.7972286343574524
# 5-fold cv val Precision score: 0.8123109936714172
# 5-fold cv val Recall score: 0.8685471415519714
# 5-fold cv val AUC score: 0.7047697901725769
# 5-fold cv val AUPR score: 0.7330434322357178
#
#
# ***********fold-6***********
# 6-fold cv val Accuracy score: 0.7960676550865173
# 6-fold cv val Precision score: 0.8091474771499634
# 6-fold cv val Recall score: 0.8689668774604797
# 6-fold cv val AUC score: 0.7087426781654358
# 6-fold cv val AUPR score: 0.7313923835754395
#
#
# ***********fold-7***********
# 7-fold cv val Accuracy score: 0.7946626543998718
# 7-fold cv val Precision score: 0.80876624584198
# 7-fold cv val Recall score: 0.8667068481445312
# 7-fold cv val AUC score: 0.710732638835907
# 7-fold cv val AUPR score: 0.734179675579071
#
#
# ***********fold-8***********
# 8-fold cv val Accuracy score: 0.7936540246009827
# 8-fold cv val Precision score: 0.8079290986061096
# 8-fold cv val Recall score: 0.8657971024513245
# 8-fold cv val AUC score: 0.7051924467086792
# 8-fold cv val AUPR score: 0.731557309627533
#
#
# ***********fold-9***********
# 9-fold cv val Accuracy score: 0.7947607040405273
# 9-fold cv val Precision score: 0.809661328792572
# 9-fold cv val Recall score: 0.8649654388427734
# 9-fold cv val AUC score: 0.7060176730155945
# 9-fold cv val AUPR score: 0.7315328121185303
#
#
# ***********fold-10***********
# 10-fold cv val Accuracy score: 0.7941817045211792
# 10-fold cv val Precision score: 0.8111668229103088
# 10-fold cv val Recall score: 0.8622143268585205
# 10-fold cv val AUC score: 0.7035938501358032
# 10-fold cv val AUPR score: 0.7300804257392883
#
#
# ******************************************************************
# -Accuracy score_mean:0.7968826293945312
# -Accuracy score_std:0.0025728277396410704
# -Precision score_mean:0.8081649541854858
# -Precision score_std:0.004139273893088102
# -Recall score_mean:0.8706945180892944
# -Recall score_std:0.0067158848978579044
# -AUC score_mean:0.7085890173912048
# -AUC score_std:0.0045515988022089005
# -AUPR score_mean:0.7325606346130371
# -AUPR score_std:0.0037860791198909283
# total running time: 9.736771627267201 minites

# %%
# 7、模型的加载使用
model2 = joblib.load('./model/context/SVM_context_10fold1.pkl')
history  = model2.fit(k_X_train,k_Y_train)
y_pre = model2.predict_proba(k_x_test)
np.save('./model/context/context_svm_pre.npy',y_pre)

m1.update_state(k_y_test,y_pre)
m2.update_state(k_y_test,y_pre)
m3.update_state(k_y_test,y_pre)
m4.update_state(k_y_test,y_pre)
m5.update_state(k_y_test,y_pre)



print(f"Accuracy score: {m1.result().numpy()}")
print(f"Precision score: {m2.result().numpy()}")
print(f"Recall score: {m3.result().numpy()}")
print(f"AUC score: {m4.result().numpy()}")
print(f"AUPR score: {m5.result().numpy()}")
# Out:
# Accuracy score: 0.8184362053871155
# Precision score: 0.8376275897026062
# Recall score: 0.8879154920578003
# AUC score: 0.7189245820045471
# AUPR score: 0.7764214873313904

# %%
# 7、模型的加载使用
model2 = joblib.load('./model/context/RF_context_10fold1.pkl')
history  = model2.fit(k_X_train,k_Y_train)
y_pre = model2.predict_proba(k_x_test)
np.save('./model/context/context_RF_pre.npy',y_pre)

m1.update_state(k_y_test,y_pre)
m2.update_state(k_y_test,y_pre)
m3.update_state(k_y_test,y_pre)
m4.update_state(k_y_test,y_pre)
m5.update_state(k_y_test,y_pre)



print(f"Accuracy score: {m1.result().numpy()}")
print(f"Precision score: {m2.result().numpy()}")
print(f"Recall score: {m3.result().numpy()}")
print(f"AUC score: {m4.result().numpy()}")
print(f"AUPR score: {m5.result().numpy()}")
# Out:
# Accuracy score: 0.7957690954208374
# Precision score: 0.8142784237861633
# Recall score: 0.8625310063362122
# AUC score: 0.7055163979530334
# AUPR score: 0.7329521179199219

# %% [markdown]
# # deepDDI

# %%
METRICS = [
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.AUC(name='auc',multi_label=True,num_labels=27,num_thresholds=498),
      keras.metrics.AUC(name='prc',curve='PR',multi_label=True,num_labels=27,num_thresholds=498), # precision-recall curve
]

def create_model_DDI(metrics=METRICS):
  model = Sequential([
    layers.Flatten(name="my_intermediate_layer"),
    layers.Dropout(0.5),
    layers.Dense(2048),
    layers.ReLU(),
    layers.Dropout(0.5),
    layers.Dense(2048),
    layers.ReLU(),
    layers.Dropout(0.5),
    layers.Dense(2048),
    layers.ReLU(),
    layers.Dropout(0.5),
    layers.Dense(2048),
    layers.ReLU(),
    layers.Dropout(0.5),
    layers.Dense(2048),
    layers.ReLU(),
    layers.Dropout(0.5),
    layers.Dense(2048),
    layers.ReLU(),
    layers.Dropout(0.5),
    layers.Dense(2048),
    layers.ReLU(),
    layers.Dropout(0.5),
    layers.Dense(2048),
    layers.ReLU(),
    layers.Dropout(0.5),
    layers.Dense(27, activation='sigmoid', name="my_last_layer"),
    ])
  return model

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau#回调函数
# # 定义回调函数：保存最优模型                     
checkpoint = ModelCheckpoint("./data/fp_cross-model.h5",
                             monitor="val_loss",
                             mode="min",
                             save_best_only = True,
                             save_weights_only=False,
                             verbose=1)
# 定义回调函数：提前终止训练
earlystop = EarlyStopping(monitor = 'val_loss', 
                          min_delta = 0.0001, 
                          patience = 30,
                          verbose = 3,
                          mode = 'min',
                          restore_best_weights = True)
# 定义回调函数：学习率衰减
reduce_lr = ReduceLROnPlateau(monitor = 'val_loss',
                              factor = 0.2,
                              patience = 5,
                              verbose = 1,
                              min_delta = 0.0001)

# 将回调函数组织为回调列表
callbacks = [earlystop,reduce_lr]

# %%
results=[]
# 运行计时部分
time_start = time.time()
print(data1.shape)

kfolder = KFold(n_splits=10,shuffle=True,random_state=2021)
for i, (tra_id,val_id) in enumerate(kfolder.split(k_X_train,k_Y_train)):
  print(f"***********fold-{i+1}***********")

  c_x_train = k_X_train[tra_id]
  c_y_train = k_Y_train.iloc[tra_id]

  c_x_valid = k_X_train[val_id]
  c_y_valid = k_Y_train.iloc[val_id]



  model = create_model_DDI()





  opt = Adam(learning_rate=0.001)
  model.compile(loss='binary_crossentropy', optimizer=opt, metrics=METRICS)
    
  # training
  history = model.fit(c_x_train,c_y_train,epochs=300,batch_size=128,
                      validation_data=(c_x_valid, c_y_valid.values),callbacks=callbacks,)
  


  y_pre = model.predict(c_x_valid)
  # y_pre1 = model.predict(k_x_test)
  # np.save('./data/FP_DDI__pre'+str(i+1)+'.npy',y_pre)

  baseline_results = model.evaluate(c_x_valid, c_y_valid.values, verbose=0)
  for name, value in zip(model.metrics_names, baseline_results):
    print(name, ': ', value)
  print()


  model.save_weights('./model/context/DDI_context_10fold'+str(i+1)+'.h5')

  result = np.array(baseline_results)
  results.append(result)



print("******************************************************************")
# print(np.array(results))

print(f"-Accuracy score_mean:{np.mean(np.array(results)[:,[1]])}")
# print(f"-Accuracy score_mean:{np.array(results)[:,[1]]}")
print(f"-Accuracy score_mean:{np.std(np.array(results)[:,[1]])}")

print(f"-Precision score_mean:{np.mean(np.array(results)[:,[2]])}")
print(f"-Precision score_mean:{np.std(np.array(results)[:,[2]])}")

print(f"-Recall score_mean:{np.mean(np.array(results)[:,[3]])}")
print(f"-Recall score_mean:{np.std(np.array(results)[:,[3]])}")

print(f"-AUC score_mean:{np.mean(np.array(results)[:,[4]])}")
print(f"-AUC score_mean:{np.std(np.array(results)[:,[4]])}")

print(f"-AUPR score_mean:{np.mean(np.array(results)[:,[5]])}")
print(f"-AUPR score_mean:{np.std(np.array(results)[:,[5]])}")






    
# 运行计时部分
time_end = time.time()
print(f"total running time: {(time_end - time_start)/60} minites")
# Out:
# (2248, 300)
# ***********fold-1***********
# Epoch 1/300
# 15/15 [==============================] - 14s 732ms/step - loss: 0.6300 - precision: 0.7392 - recall: 0.7770 - accuracy: 0.6974 - auc: 0.4956 - prc: 0.6098 - val_loss: 0.5312 - val_precision: 0.7707 - val_recall: 0.8526 - val_accuracy: 0.7583 - val_auc: 0.5196 - val_prc: 0.5929 - lr: 0.0010
# Epoch 2/300
# 15/15 [==============================] - 10s 660ms/step - loss: 0.5191 - precision: 0.7651 - recall: 0.8658 - accuracy: 0.7565 - auc: 0.5061 - prc: 0.6064 - val_loss: 0.5083 - val_precision: 0.7429 - val_recall: 0.9131 - val_accuracy: 0.7572 - val_auc: 0.5912 - val_prc: 0.6321 - lr: 0.0010
# Epoch 3/300
# 15/15 [==============================] - 10s 656ms/step - loss: 0.5082 - precision: 0.7545 - recall: 0.8893 - accuracy: 0.7566 - auc: 0.5202 - prc: 0.6166 - val_loss: 0.5068 - val_precision: 0.7707 - val_recall: 0.8526 - val_accuracy: 0.7583 - val_auc: 0.5891 - val_prc: 0.6470 - lr: 0.0010
# Epoch 4/300
# 15/15 [==============================] - 10s 657ms/step - loss: 0.5035 - precision: 0.7623 - recall: 0.8739 - accuracy: 0.7574 - auc: 0.5401 - prc: 0.6270 - val_loss: 0.4984 - val_precision: 0.7422 - val_recall: 0.9170 - val_accuracy: 0.7581 - val_auc: 0.6421 - val_prc: 0.6709 - lr: 0.0010
# Epoch 5/300
# 15/15 [==============================] - 10s 656ms/step - loss: 0.5033 - precision: 0.7599 - recall: 0.8810 - accuracy: 0.7581 - auc: 0.5455 - prc: 0.6313 - val_loss: 0.4917 - val_precision: 0.7526 - val_recall: 0.9025 - val_accuracy: 0.7625 - val_auc: 0.6507 - val_prc: 0.6712 - lr: 0.0010
# Epoch 6/300
# 15/15 [==============================] - 10s 655ms/step - loss: 0.4999 - precision: 0.7573 - recall: 0.8919 - accuracy: 0.7603 - auc: 0.5726 - prc: 0.6436 - val_loss: 0.4903 - val_precision: 0.7738 - val_recall: 0.8680 - val_accuracy: 0.7676 - val_auc: 0.6584 - val_prc: 0.6832 - lr: 0.0010
# Epoch 7/300
# 15/15 [==============================] - 10s 651ms/step - loss: 0.4939 - precision: 0.7679 - recall: 0.8769 - accuracy: 0.7638 - auc: 0.5904 - prc: 0.6572 - val_loss: 0.4848 - val_precision: 0.7684 - val_recall: 0.8801 - val_accuracy: 0.7679 - val_auc: 0.6460 - val_prc: 0.6759 - lr: 0.0010
# Epoch 8/300
# Epoch 54/300
# 15/15 [==============================] - 10s 670ms/step - loss: 0.4268 - precision: 0.8168 - recall: 0.8685 - accuracy: 0.8021 - auc: 0.7521 - prc: 0.7472 - val_loss: 0.4825 - val_precision: 0.8121 - val_recall: 0.8480 - val_accuracy: 0.7836 - val_auc: 0.6585 - val_prc: 0.6923 - lr: 3.2000e-07
# Epoch 55/300
# 15/15 [==============================] - ETA: 0s - loss: 0.4228 - precision: 0.8188 - recall: 0.8688 - accuracy: 0.8039 - auc: 0.7609 - prc: 0.7510Restoring model weights from the end of the best epoch: 25.
#
# Epoch 00055: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# 15/15 [==============================] - 10s 667ms/step - loss: 0.4228 - precision: 0.8188 - recall: 0.8688 - accuracy: 0.8039 - auc: 0.7609 - prc: 0.7510 - val_loss: 0.4825 - val_precision: 0.8121 - val_recall: 0.8480 - val_accuracy: 0.7836 - val_auc: 0.6584 - val_prc: 0.6923 - lr: 3.2000e-07
# Epoch 00055: early stopping
# loss :  0.4651598036289215
# precision :  0.8022156357765198
# recall :  0.8760696649551392
# accuracy :  0.7887789011001587
# auc :  0.6635172963142395
# prc :  0.6956073045730591
#
# ******************************************************************
# -Accuracy score_mean:0.7919307947158813
# -Accuracy score_mean:0.016382038520641993
# -Precision score_mean:0.8658001482486725
# -Precision score_mean:0.022646317136503665
# -Recall score_mean:0.7801140367984771
# -Recall score_mean:0.012271346849737269
# -AUC score_mean:0.664855694770813
# -AUC score_mean:0.012430158590563175
# -AUPR score_mean:0.697351998090744
# -AUPR score_mean:0.014746957846191167
# total running time: 91.82510754664739 minites

# %%
#加载模型
from keras.models import load_model
# model.load_weights(‘model_weights.h5')
model2 = create_model_DDI()

model2.build(k_X_train.shape)#加这一步有了解决

model2.load_weights('./model/context/DDI_context_10fold3.h5')

opt = Adam(learning_rate=0.001)
model2.compile(loss='binary_crossentropy', optimizer=opt, metrics=METRICS)
model2.fit(k_X_train,k_Y_train,batch_size=128, epochs=300,validation_data=(k_x_test,k_y_test),callbacks=[earlystop])
model2.evaluate(k_x_test,k_y_test,return_dict=True)
y_pre = model2.predict(k_x_test)
np.save('./model/context/context_DDI_pre.npy',y_pre)
# Out:
# Epoch 1/300
# 16/16 [==============================] - 17s 878ms/step - loss: 0.4574 - precision: 0.8024 - recall: 0.8652 - accuracy: 0.7881 - auc: 0.6979 - prc: 0.7101 - val_loss: 0.4411 - val_precision: 0.8148 - val_recall: 0.8830 - val_accuracy: 0.7970 - val_auc: 0.6948 - val_prc: 0.7255
# Epoch 2/300
# 16/16 [==============================] - 11s 674ms/step - loss: 0.4515 - precision: 0.8005 - recall: 0.8716 - accuracy: 0.7899 - auc: 0.7111 - prc: 0.7145 - val_loss: 0.4478 - val_precision: 0.8251 - val_recall: 0.8518 - val_accuracy: 0.7900 - val_auc: 0.7038 - val_prc: 0.7224
# Epoch 3/300
